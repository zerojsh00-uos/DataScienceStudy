# %% [markdown]
# # 자연어 처리 시작하기

# %% [markdown]
# 데이터 분석이 인기를 끌고 있는 요즘 이론적 배경에 대한 이해는 부족하더라도 자연어 처리 모듈의 일부 기능을 사용해야 하는 빈도가 조금씩 많아지고 있다. 자연어 처리 전무낙가 아니라도 웹 데이터를 다루다 보면 정형화된 데이터에서 단순 텍스트 분석 등의 역할에 대한 니즈가 있다. 7장의 예측(forecast)처럼 이론적 배경보다 일단 응용의 필요에 맞춰 이번 장을 진행할 것이다. 그러나 그것이 이론적 배경 없이 모듈만 사용하는 것이 좋다는 의미는 아니다.

# %% [markdown]
# ## 8-1 한글 자연어 처리 기초 - KoNLPy 및 필요 모듈의 설치

# %% [markdown]
# 한글 자연어 처리를 파이썬으로 하는 것을 도와주는 모듈은 Lucy Park이라는 분이 개발한 KoNLPy 모듈이 필수이다. Lucy Park 님을 검색해보면 KoNLPy의 다양한 튜토리얼과 많은 배울 것들이 있다. 꼭 블로그를 방문해서 탄탄한 기초를 다지길 바란다. 특히 Lucy Park 님의 Github ID를 검색해보면 많은 좋은 코드를 볼 수 있다. 공부하는 데 도움이 될 것이다. 아래는 제 26회 한글 및 한국어 정보처리 학술대회 논문집에 Lucy Park 님이 KoNLPy를 개발한 결과를 발표한 논문의 요악이다.

# %% [markdown]
# *파이썬은 간결한 아름다움을 추구하는 동시에 강력한 스트링 연산이 가능한 언어다. KoNLPy는 그러한 특장점을 살려, 파이썬으로 한국어 정보처리를 할 수 있게 하는 패키지이다. 꼬꼬마, 한나눔, MeCab-ko 등 국내외에서 개발된 여러 형태소 분석기를 포함하고, 자연어 처리에 필요한 각종 사전, 말뭉치, 도구 및 다양한 튜토리얼을 포함하여 손쉽게 한국어 분석을 할 수 있도록 만들었다.*
#
# <div style="text-align: right">*- KoNLPy : 쉽고 간결한 한국어 정보처리 파이썬 패키지의 요약문*</div>

# %% [markdown]
# KoNLPy를 사용하기 위해서는 몇몇 약간은 복잡할 수 있는 설치 과정을 거쳐야 한다. 먼저 터미널에서 **pip install konlpy** 명령으로 konlpy를 설치한다. 그리고 Java SDK 다운로드 페이지에서 JDK를 다운로드 해야한다.
#
# 윈도우 유저라면 환경변수 설정을 해주어야 한다.(책 참고) 맥 OS 유저라면 **'JAVA_HOME=$(/usr/libexec/java_home)'**이라고 입력하면 된다. 그리고 터미널에서 **'pip install Jpype1-py3'**라고 입력하여 설치한다. JPype1의 경우 인터넷 포럼을 보면 설치에 어려움을 경험한 사람들이 많다. 설치한 운영체제 버전, JDK 버전, Jupyter를 설치한 경로에 한글이 있을 때, PC 이름에 한글이 있을 때 등 그 원인도 다양하다. 설치 문제가 생겼을 때  그 원인을 구글에서 검색해야 할 수도 있다. 그러나 확실한 것은 분명 잘 설치되어 사용하는 사람들이 많으니 참을성 있게 시도해보기 바란다.

# %% [markdown]
# ## 8-2 한글 자연어 처리 기초

# %% [markdown]
# 8-1 절에서 Lucy Park 님의 논문 요약문에도 나타나 있지만 KoNLPy는 꼬꼬마, 한나눔 등의 엔진을 사용할 수 있게 해준다.

# %%
# 꼬꼬마 모듈

from konlpy.tag import Kkma
kkma = Kkma()

# %% [markdown]
# 먼저 꼬꼬마 모듈을 사용할 수 있다.

# %%
kkma.sentences('한국어 분석을 시작합니다 재미있어요~~')
# Out:
# ['한국어 분석을 시작합니다', '재미있어요~~']

# %% [markdown]
# 위와 같이 문장 분석을 한다. ~~ 시작합니다 재미있어요 ~~ 에서 마침표(.)가 없어도 두 개의 문장으로 구분한다.

# %%
kkma.nouns('한국어 분석을 시작합니다 재미있어요~~')
# Out:
# ['한국어', '분석']

# %% [markdown]
# 위와 같이 명사 분석도 수행한다.

# %%
kkma.sentences('하나님 아버지, 벌써 3시네요. 자기전에 잠깐 기도를 드립니다. 주님, 어젠 참 정신없이 지나갔습니다. 어머님이 일반병실로 옮기셔서 진실이는 병원에서 상주하고 있게 되었습니다. 하나님, 먼저 어머님 열과 염증, 그리고 혈압이 불안합니다. 지금까지 어머님의 모든 회복을 이끌고계신 주님, 저희의 기도가 멈추지 않았고 끝까지 기도하옵기로는 모든 비정상적 수치들이 정상화 되고, 어머님의 소장까지 치유되어 하루빨리 가족의 품에서 맛있는 식사를 함께할 수 있기를 구합니다. 특히 우리 진실이 위해 기도합니다. 병간호가 너무나 힘든데, 사랑하는 마음과는 별개로 몸과 마음이 지칩니다. 주님 , 진실이 위해서 기도하는 많은 사람들의 바람처럼 진실이도 지치지 않고 체력적으로나 정신적으로나 건강할 수 있기를 구합니다. 간호 중 어려운 점들이 있다면 주님께서 또한 채워주시고 위로하여 주옵소서. 이제 잡니다. 내일도 주님을 신뢰하며 걷길 원합니다. 동행하여 주옵소서. 예수님의 이름으로 기도드립니다. 아멘')
# Out:
# ['하나님 아버지, 벌써 3시네요.',
#  '자기 전에 잠깐 기도를 드립니다.',
#  '주님, 어 젠 참 정신없이 지나갔습니다.',
#  '어머님이 일반 병실로 옮기셔서 진실이 는 병원에서 상주하고 있게 되었습니다.',
#  '하나님, 먼저 어머님 열과 염증, 그리고 혈압이 불안합니다.',
#  '지금까지 어머님의 모든 회복을 이끌고 계신 주님, 저희의 기도가 멈추지 않았고 끝까지 기도하옵기로는 모든 비정상적 수치들이 정상화 되고, 어머님의 소장까지 치유되어 하루빨리 가족의 품에서 맛있는 식사를 함께 할 수 있기를 구합니다.',
#  '특히 우리 진실이 위해 기도합니다.',
#  '병간호가 너무나 힘든데, 사랑하는 마음과는 별개로 몸과 마음이 지칩니다.',
#  '주님 , 진실이 위해서 기도하는 많은 사람들의 바람처럼 진실 이도 지치지 않고 체력적으로 나 정신적으로 나 건강할 수 있기를 구합니다.',
#  '간호 중 어려운 점들이 있다면 주님께서 또한 채워 주시고 위로하여 주옵소서.',
#  '이제 잡니다.',
#  '내 일도 주님을 신뢰하며 걷길 원합니다.',
#  '동행하여 주옵소서.',
#  '예수님의 이름으로 기도 드립니다.',
#  '아멘']

# %%
kkma.nouns('하나님 아버지, 벌써 3시네요. 자기전에 잠깐 기도를 드립니다. 주님, 어젠 참 정신없이 지나갔습니다. 어머님이 일반병실로 옮기셔서 진실이는 병원에서 상주하고 있게 되었습니다. 하나님, 먼저 어머님 열과 염증, 그리고 혈압이 불안합니다. 지금까지 어머님의 모든 회복을 이끌고계신 주님, 저희의 기도가 멈추지 않았고 끝까지 기도하옵기로는 모든 비정상적 수치들이 정상화 되고, 어머님의 소장까지 치유되어 하루빨리 가족의 품에서 맛있는 식사를 함께할 수 있기를 구합니다. 특히 우리 진실이 위해 기도합니다. 병간호가 너무나 힘든데, 사랑하는 마음과는 별개로 몸과 마음이 지칩니다. 주님 , 진실이 위해서 기도하는 많은 사람들의 바람처럼 진실이도 지치지 않고 체력적으로나 정신적으로나 건강할 수 있기를 구합니다. 간호 중 어려운 점들이 있다면 주님께서 또한 채워주시고 위로하여 주옵소서. 이제 잡니다. 내일도 주님을 신뢰하며 걷길 원합니다. 동행하여 주옵소서. 예수님의 이름으로 기도드립니다. 아멘')
# Out:
# ['하나님',
#  '아버지',
#  '3',
#  '3시',
#  '시',
#  '전',
#  '기도',
#  '주',
#  '젠',
#  '어머님',
#  '일반',
#  '일반병실',
#  '병실',
#  '진실',
#  '병원',
#  '상주',
#  '열과',
#  '염증',
#  '혈압',
#  '불안',
#  '지금',
#  '모든',
#  '회복',
#  '계신',
#  '저희',
#  '끝',
#  '비정상',
#  '수치',
#  '정상화',
#  '소장',
#  '치유',
#  '가족',
#  '품',
#  '식사',
#  '수',
#  '우리',
#  '위',
#  '병간호',
#  '사랑',
#  '마음',
#  '별개',
#  '몸',
#  '사람',
#  '바람',
#  '진실이도',
#  '이도',
#  '체력',
#  '정신적',
#  '건강',
#  '간호',
#  '중',
#  '점',
#  '위로',
#  '내',
#  '일도',
#  '신뢰',
#  '동행',
#  '예수',
#  '이름',
#  '아멘']

# %%
kkma.pos('하나님 아버지, 벌써 3시네요. 자기전에 잠깐 기도를 드립니다. 주님, 어젠 참 정신없이 지나갔습니다. 어머님이 일반병실로 옮기셔서 진실이는 병원에서 상주하고 있게 되었습니다. 하나님, 먼저 어머님 열과 염증, 그리고 혈압이 불안합니다. 지금까지 어머님의 모든 회복을 이끌고계신 주님, 저희의 기도가 멈추지 않았고 끝까지 기도하옵기로는 모든 비정상적 수치들이 정상화 되고, 어머님의 소장까지 치유되어 하루빨리 가족의 품에서 맛있는 식사를 함께할 수 있기를 구합니다. 특히 우리 진실이 위해 기도합니다. 병간호가 너무나 힘든데, 사랑하는 마음과는 별개로 몸과 마음이 지칩니다. 주님 , 진실이 위해서 기도하는 많은 사람들의 바람처럼 진실이도 지치지 않고 체력적으로나 정신적으로나 건강할 수 있기를 구합니다. 간호 중 어려운 점들이 있다면 주님께서 또한 채워주시고 위로하여 주옵소서. 이제 잡니다. 내일도 주님을 신뢰하며 걷길 원합니다. 동행하여 주옵소서. 예수님의 이름으로 기도드립니다. 아멘')
# Out:
# [('하나님', 'NNG'),
#  ('아버지', 'NNG'),
#  (',', 'SP'),
#  ('벌써', 'MAG'),
#  ('3', 'NR'),
#  ('시', 'NNM'),
#  ('이', 'VCP'),
#  ('네요', 'EFN'),
#  ('.', 'SF'),
#  ('자', 'VA'),
#  ('기', 'ETN'),
#  ('전', 'NNG'),
#  ('에', 'JKM'),
#  ('잠깐', 'MAG'),
#  ('기도', 'NNG'),
#  ('를', 'JKO'),
#  ('드리', 'VV'),
#  ('ㅂ니다', 'EFN'),
#  ('.', 'SF'),
#  ('주', 'NNG'),
#  ('님', 'XSN'),
#  (',', 'SP'),
#  ('어', 'VV'),
#  ('어', 'ECS'),
#  ('젠', 'UN'),
#  ('참', 'MAG'),
#  ('정신없이', 'MAG'),
#  ('지나가', 'VV'),
#  ('었', 'EPT'),
#  ('습니다', 'EFN'),
#  ('.', 'SF'),
#  ('어머님', 'NNG'),
#  ('이', 'JKS'),
#  ('일반', 'NNG'),
#  ('병실', 'NNG'),
#  ('로', 'JKM'),
#  ('옮기', 'VV'),
#  ('시', 'EPH'),
#  ('어서', 'ECD'),
#  ('진실', 'NNG'),
#  ('이', 'JKS'),
#  ('늘', 'VV'),
#  ('ㄴ', 'ETD'),
#  ('병원', 'NNG'),
#  ('에서', 'JKM'),
#  ('상주', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'ECE'),
#  ('있', 'VXV'),
#  ('게', 'ECD'),
#  ('되', 'VV'),
#  ('었', 'EPT'),
#  ('습니다', 'EFN'),
#  ('.', 'SF'),
#  ('하나님', 'NNG'),
#  (',', 'SP'),
#  ('먼저', 'MAG'),
# ...

# %% [markdown]
# 위와 같이 형태소 분석도 수행한다. 한글은 영어와 달리 단어의 형태 변화가 많아서 영어처럼 쉽게 접근하기가 어렵다. 그래서 최소한의 의미 단위인 형태소로 언어를 분석하는 것이 일반적이다.

# %%
from konlpy.tag import Hannanum
hannanum = Hannanum()

# %% [markdown]
# 이제 한나눔을 사용해보자!

# %%
hannanum.nouns('하나님 아버지, 벌써 3시네요. 자기전에 잠깐 기도를 드립니다. 주님, 어젠 참 정신없이 지나갔습니다. 어머님이 일반병실로 옮기셔서 진실이는 병원에서 상주하고 있게 되었습니다. 하나님, 먼저 어머님 열과 염증, 그리고 혈압이 불안합니다. 지금까지 어머님의 모든 회복을 이끌고계신 주님, 저희의 기도가 멈추지 않았고 끝까지 기도하옵기로는 모든 비정상적 수치들이 정상화 되고, 어머님의 소장까지 치유되어 하루빨리 가족의 품에서 맛있는 식사를 함께할 수 있기를 구합니다. 특히 우리 진실이 위해 기도합니다. 병간호가 너무나 힘든데, 사랑하는 마음과는 별개로 몸과 마음이 지칩니다. 주님 , 진실이 위해서 기도하는 많은 사람들의 바람처럼 진실이도 지치지 않고 체력적으로나 정신적으로나 건강할 수 있기를 구합니다. 간호 중 어려운 점들이 있다면 주님께서 또한 채워주시고 위로하여 주옵소서. 이제 잡니다. 내일도 주님을 신뢰하며 걷길 원합니다. 동행하여 주옵소서. 예수님의 이름으로 기도드립니다. 아멘')
# Out:
# ['하나님',
#  '아버지',
#  '3시',
#  '자기전',
#  '기도',
#  '주님',
#  '어젠',
#  '정신',
#  '어머님',
#  '일반병실',
#  '진실',
#  '병원',
#  '상주',
#  '하나님,',
#  '어머님',
#  '열',
#  '염증',
#  '혈압',
#  '불안',
#  '지금',
#  '어머님',
#  '회복',
#  '주님',
#  '저희',
#  '기도',
#  '끝',
#  '기도하옵기로는',
#  '비정상적',
#  '수치들',
#  '정상화',
#  '어머님',
#  '소장',
#  '치유',
#  '가족',
#  '식사',
#  '수',
#  '우리',
#  '진실',
#  '기도',
#  '병',
#  '호',
#  '사랑',
#  '마음',
#  '별개',
#  '몸',
#  '마음',
#  '주님',
#  '진실',
#  '기도',
#  '사람',
#  '진실',
#  '체력적',
#  '정신적',
#  '건강',
#  '수',
#  '간호',
#  '중',
#  '점',
#  '주님',
#  '위로',
#  '주옵소서',
#  '내일',
#  '주님',
#  '신뢰',
#  '걷길',
#  '동행',
#  '주옵소서',
#  '예수님',
#  '이름',
#  '아멘']

# %%
hannanum.morphs('하나님 아버지, 벌써 3시네요. 자기전에 잠깐 기도를 드립니다. 주님, 어젠 참 정신없이 지나갔습니다. 어머님이 일반병실로 옮기셔서 진실이는 병원에서 상주하고 있게 되었습니다. 하나님, 먼저 어머님 열과 염증, 그리고 혈압이 불안합니다. 지금까지 어머님의 모든 회복을 이끌고계신 주님, 저희의 기도가 멈추지 않았고 끝까지 기도하옵기로는 모든 비정상적 수치들이 정상화 되고, 어머님의 소장까지 치유되어 하루빨리 가족의 품에서 맛있는 식사를 함께할 수 있기를 구합니다. 특히 우리 진실이 위해 기도합니다. 병간호가 너무나 힘든데, 사랑하는 마음과는 별개로 몸과 마음이 지칩니다. 주님 , 진실이 위해서 기도하는 많은 사람들의 바람처럼 진실이도 지치지 않고 체력적으로나 정신적으로나 건강할 수 있기를 구합니다. 간호 중 어려운 점들이 있다면 주님께서 또한 채워주시고 위로하여 주옵소서. 이제 잡니다. 내일도 주님을 신뢰하며 걷길 원합니다. 동행하여 주옵소서. 예수님의 이름으로 기도드립니다. 아멘')
# Out:
# ['하나님',
#  '아버지',
#  ',',
#  '벌써',
#  '3시',
#  '이',
#  '네',
#  '요',
#  '.',
#  '자기전',
#  '에',
#  '잠깐',
#  '기도',
#  '를',
#  '드리',
#  'ㅂ니다',
#  '.',
#  '주님',
#  ',',
#  '어젠',
#  '참',
#  '정신',
#  '없이',
#  '지나',
#  '아',
#  '가',
#  '아ㅂ니다',
#  '.',
#  '어머님',
#  '이',
#  '일반병실',
#  '로',
#  '옮기',
#  '시어서',
#  '진실',
#  '이',
#  '는',
#  '병원',
#  '에서',
#  '상주',
#  '하고',
#  '있',
#  '게',
#  '되',
#  '었습니다',
#  '.',
#  '하나님,',
#  '먼저',
#  '어머님',
#  '열',
#  '과',
#  '염증',
#  ',',
#  '그리고',
#  '혈압',
#  '이',
#  '불안',
#  '하',
#  'ㅂ니다',
#  '.',
#  '지금',
#  '까지',
#  '어머님',
#  '의',
#  '모든',
#  '회복',
#  '을',
#  '이끌',
#  '고',
#  '계시',
#  'ㄴ',
#  '주님',
#  ',',
#  '저희',
#  '의',
#  '기도',
#  '가',
#  '멈추',
#  '지',
#  '않',
#  '아고',
#  '끝',
#  '까지',
#  '기도하옵기로는',
#  '모든',
#  '비정상적',
#  '수치들',
#  '이',
#  '정상화',
#  '되',
#  '고',
#  ',',
#  '어머님',
#  '의',
#  '소장',
#  '까지',
#  '치유',
#  '되',
#  '어',
#  '하루빨리',
#  '가족',
#  '의',
#  '풀',
#  'ㅁ',
#  '에서',
#  '맛있',
#  '는',
#  '식사',
#  '를',
#  '함께하',
#  'ㄹ',
#  '수',
#  '있',
# ...

# %% [markdown]
# 위와 같이 한나눔도 형태소 분석을 할 수 있다.
#
# 이번에는 트위터(Twitter) 분석이다.

# %%
from konlpy.tag import Twitter
t = Twitter()

# %%
t.nouns('하나님 아버지, 벌써 3시네요. 자기전에 잠깐 기도를 드립니다. 주님, 어젠 참 정신없이 지나갔습니다. 어머님이 일반병실로 옮기셔서 진실이는 병원에서 상주하고 있게 되었습니다. 하나님, 먼저 어머님 열과 염증, 그리고 혈압이 불안합니다. 지금까지 어머님의 모든 회복을 이끌고계신 주님, 저희의 기도가 멈추지 않았고 끝까지 기도하옵기로는 모든 비정상적 수치들이 정상화 되고, 어머님의 소장까지 치유되어 하루빨리 가족의 품에서 맛있는 식사를 함께할 수 있기를 구합니다. 특히 우리 진실이 위해 기도합니다. 병간호가 너무나 힘든데, 사랑하는 마음과는 별개로 몸과 마음이 지칩니다. 주님 , 진실이 위해서 기도하는 많은 사람들의 바람처럼 진실이도 지치지 않고 체력적으로나 정신적으로나 건강할 수 있기를 구합니다. 간호 중 어려운 점들이 있다면 주님께서 또한 채워주시고 위로하여 주옵소서. 이제 잡니다. 내일도 주님을 신뢰하며 걷길 원합니다. 동행하여 주옵소서. 예수님의 이름으로 기도드립니다. 아멘')
# Out:
# ['하나님',
#  '아버지',
#  '벌써',
#  '시',
#  '잠깐',
#  '기도',
#  '주님',
#  '어젠',
#  '어머님',
#  '일반',
#  '병실',
#  '진실',
#  '병원',
#  '상주',
#  '하나님',
#  '먼저',
#  '어머님',
#  '열',
#  '염증',
#  '혈압',
#  '지금',
#  '어머님',
#  '모든',
#  '회복',
#  '주님',
#  '저희',
#  '기도',
#  '끝',
#  '기',
#  '도하',
#  '옵기',
#  '모든',
#  '비정상',
#  '수치',
#  '정상화',
#  '어머님',
#  '소장',
#  '치유',
#  '가족',
#  '품',
#  '식사',
#  '수',
#  '우리',
#  '진실',
#  '위해',
#  '기도',
#  '병간호',
#  '너무나',
#  '마음',
#  '별개',
#  '몸',
#  '마음',
#  '주님',
#  '진실',
#  '기도',
#  '사람',
#  '바람',
#  '진실',
#  '체력',
#  '정신',
#  '수',
#  '간호',
#  '중',
#  '점',
#  '주님',
#  '또한',
#  '주',
#  '이제',
#  '내일',
#  '주님',
#  '신뢰',
#  '동행',
#  '주',
#  '예수님',
#  '이름',
#  '기도',
#  '아멘']

# %%
t.morphs('하나님 아버지, 벌써 3시네요. 자기전에 잠깐 기도를 드립니다. 주님, 어젠 참 정신없이 지나갔습니다. 어머님이 일반병실로 옮기셔서 진실이는 병원에서 상주하고 있게 되었습니다. 하나님, 먼저 어머님 열과 염증, 그리고 혈압이 불안합니다. 지금까지 어머님의 모든 회복을 이끌고계신 주님, 저희의 기도가 멈추지 않았고 끝까지 기도하옵기로는 모든 비정상적 수치들이 정상화 되고, 어머님의 소장까지 치유되어 하루빨리 가족의 품에서 맛있는 식사를 함께할 수 있기를 구합니다. 특히 우리 진실이 위해 기도합니다. 병간호가 너무나 힘든데, 사랑하는 마음과는 별개로 몸과 마음이 지칩니다. 주님 , 진실이 위해서 기도하는 많은 사람들의 바람처럼 진실이도 지치지 않고 체력적으로나 정신적으로나 건강할 수 있기를 구합니다. 간호 중 어려운 점들이 있다면 주님께서 또한 채워주시고 위로하여 주옵소서. 이제 잡니다. 내일도 주님을 신뢰하며 걷길 원합니다. 동행하여 주옵소서. 예수님의 이름으로 기도드립니다. 아멘')
# Out:
# ['하나님',
#  '아버지',
#  ',',
#  '벌써',
#  '3',
#  '시',
#  '네',
#  '요',
#  '.',
#  '자기',
#  '전',
#  '에',
#  '잠깐',
#  '기도',
#  '를',
#  '드립니',
#  '다',
#  '.',
#  '주님',
#  ',',
#  '어젠',
#  '참',
#  '정신없이',
#  '지나갔',
#  '습니다',
#  '.',
#  '어머님',
#  '이',
#  '일반',
#  '병실',
#  '로',
#  '옮기',
#  '셔',
#  '서',
#  '진실',
#  '이',
#  '는',
#  '병원',
#  '에서',
#  '상주',
#  '하고',
#  '있게',
#  '되었',
#  '습니다',
#  '.',
#  '하나님',
#  ',',
#  '먼저',
#  '어머님',
#  '열',
#  '과',
#  '염증',
#  ',',
#  '그리고',
#  '혈압',
#  '이',
#  '불안합',
#  '니다',
#  '.',
#  '지금',
#  '까지',
#  '어머님',
#  '의',
#  '모든',
#  '회복',
#  '을',
#  '이끌',
#  '고',
#  '계',
#  '신',
#  '주님',
#  ',',
#  '저희',
#  '의',
#  '기도',
#  '가',
#  '멈추지',
#  '않았',
#  '고',
#  '끝',
#  '까지',
#  '기',
#  '도하',
#  '옵기',
#  '로는',
#  '모든',
#  '비정상',
#  '적',
#  '수치',
#  '들',
#  '이',
#  '정상화',
#  '되',
#  '고',
#  ',',
#  '어머님',
#  '의',
#  '소장',
#  '까지',
#  '치유',
#  '되어',
#  '하루빨리',
#  '가족',
#  '의',
#  '품',
#  '에서',
#  '맛있는',
#  '식사',
#  '를',
#  '함께할',
#  '수',
#  '있기',
#  '를',
#  '구합',
# ...

# %%
t.pos('하나님 아버지, 벌써 3시네요. 자기전에 잠깐 기도를 드립니다. 주님, 어젠 참 정신없이 지나갔습니다. 어머님이 일반병실로 옮기셔서 진실이는 병원에서 상주하고 있게 되었습니다. 하나님, 먼저 어머님 열과 염증, 그리고 혈압이 불안합니다. 지금까지 어머님의 모든 회복을 이끌고계신 주님, 저희의 기도가 멈추지 않았고 끝까지 기도하옵기로는 모든 비정상적 수치들이 정상화 되고, 어머님의 소장까지 치유되어 하루빨리 가족의 품에서 맛있는 식사를 함께할 수 있기를 구합니다. 특히 우리 진실이 위해 기도합니다. 병간호가 너무나 힘든데, 사랑하는 마음과는 별개로 몸과 마음이 지칩니다. 주님 , 진실이 위해서 기도하는 많은 사람들의 바람처럼 진실이도 지치지 않고 체력적으로나 정신적으로나 건강할 수 있기를 구합니다. 간호 중 어려운 점들이 있다면 주님께서 또한 채워주시고 위로하여 주옵소서. 이제 잡니다. 내일도 주님을 신뢰하며 걷길 원합니다. 동행하여 주옵소서. 예수님의 이름으로 기도드립니다. 아멘')
# Out:
# [('하나님', 'Noun'),
#  ('아버지', 'Noun'),
#  (',', 'Punctuation'),
#  ('벌써', 'Noun'),
#  ('3', 'Number'),
#  ('시', 'Noun'),
#  ('네', 'Suffix'),
#  ('요', 'Josa'),
#  ('.', 'Punctuation'),
#  ('자기', 'Verb'),
#  ('전', 'PreEomi'),
#  ('에', 'Eomi'),
#  ('잠깐', 'Noun'),
#  ('기도', 'Noun'),
#  ('를', 'Josa'),
#  ('드립니', 'Verb'),
#  ('다', 'Eomi'),
#  ('.', 'Punctuation'),
#  ('주님', 'Noun'),
#  (',', 'Punctuation'),
#  ('어젠', 'Noun'),
#  ('참', 'Verb'),
#  ('정신없이', 'Adverb'),
#  ('지나갔', 'Verb'),
#  ('습니다', 'Eomi'),
#  ('.', 'Punctuation'),
#  ('어머님', 'Noun'),
#  ('이', 'Josa'),
#  ('일반', 'Noun'),
#  ('병실', 'Noun'),
#  ('로', 'Josa'),
#  ('옮기', 'Verb'),
#  ('셔', 'PreEomi'),
#  ('서', 'Eomi'),
#  ('진실', 'Noun'),
#  ('이', 'Suffix'),
#  ('는', 'Josa'),
#  ('병원', 'Noun'),
#  ('에서', 'Josa'),
#  ('상주', 'Noun'),
#  ('하고', 'Josa'),
#  ('있게', 'Adjective'),
#  ('되었', 'Verb'),
#  ('습니다', 'Eomi'),
#  ('.', 'Punctuation'),
#  ('하나님', 'Noun'),
#  (',', 'Punctuation'),
#  ('먼저', 'Noun'),
#  ('어머님', 'Noun'),
# ...

# %% [markdown]
# ## 8-3 워드 클라우드

# %% [markdown]
# 워드 클라우드(word cloud)는 자주 나타나는 단어를 크게 보여줌으로써 직관적으로 텍스트를 알리는데 도움을 준다. 파이썬에서 사용할 수 있는 워드 클라우드도 몇 가지 있다. 설치는 이미 8-1 절에서 했으니 워드 클라우드 공식 Github에서 배포하는 튜토리얼을 일부 수정한 것을 우리도 튜토리얼하고 다음 절로 넘어가보자.

# %%
from wordcloud import WordCloud, STOPWORDS
import numpy as np
from PIL import Image

# %% [markdown]
# 먼저 필요한 몇몇 모듈을 import 한다. 그리고 이상한 나라의 앨리스 영문 버전을 다운받아서 data 폴더에 저장하고 읽는다. 또한 앨리스 그림도 저장한다.

# %%
text = open('../data/09. alice.txt').read()
alice_mask = np.array(Image.open('../data/09. alice_mask.png'))

stopwords = set(STOPWORDS)
stopwords.add("said") # said 라는 단어를 제거함

# %%
import matplotlib.pyplot as plt
import platform

from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
    
# %matplotlib inline

# %%
plt.figure(figsize=(8,8))
plt.imshow(alice_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# 이제 문서 자체에서 단어를 카운트하는 기능을 워드 클라우드가 제공하니 그것을 사용해서 최빈 단어를 찾는다.

# %%
wc = WordCloud(background_color='white', max_words=2000, mask=alice_mask,
              stopwords = stopwords)
wc = wc.generate(text)
wc.words_
# Out:
# {'Alice': 1.0,
#  'little': 0.2958904109589041,
#  'one': 0.2602739726027397,
#  'know': 0.2465753424657534,
#  'went': 0.2273972602739726,
#  'thing': 0.2191780821917808,
#  'time': 0.21095890410958903,
#  'Queen': 0.20821917808219179,
#  'see': 0.18356164383561643,
#  'King': 0.17534246575342466,
#  'now': 0.1643835616438356,
#  'began': 0.1589041095890411,
#  'way': 0.15616438356164383,
#  'Hatter': 0.15616438356164383,
#  'head': 0.15342465753424658,
#  'Mock Turtle': 0.15342465753424658,
#  'say': 0.1506849315068493,
#  'Gryphon': 0.1506849315068493,
#  'well': 0.14794520547945206,
#  'think': 0.14520547945205478,
#  'quite': 0.14246575342465753,
#  'much': 0.13972602739726028,
#  'first': 0.13972602739726028,
#  'go': 0.136986301369863,
#  'thought': 0.13424657534246576,
#  'come': 0.13150684931506848,
#  'never': 0.12876712328767123,
#  'voice': 0.12602739726027398,
#  'looked': 0.1232876712328767,
#  'got': 0.1232876712328767,
#  'must': 0.12054794520547946,
# ...

# %%
plt.figure(figsize=(12,12))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
text = open('../data/09. a_new_hope.txt').read()

text = text.replace('HAN', 'Han')
text = text.replace("LUKE'S", 'Luke')

mask = np.array(Image.open('../data/09. stormtrooper_mask.png'))

# %%
stopwords = set(STOPWORDS)
stopwords.add("int")
stopwords.add("ext")

# %% [markdown]
# 위와 같이 특수하게 처리할 단어들을 처리한 후 워드클라우드를 준비한다.

# %%
wc = WordCloud(max_words=1000, mask = mask, stopwords=stopwords,
              margin = 10 , random_state=1).generate(text)

default_colors = wc.to_array()

# %% [markdown]
# 이번에는 앨리스와는 약간 달리 색상을 전체적으로 회색(grey)으로 채우도록 함수를 하나 만들어 둔다.

# %%
import random
def grey_color_func(word, font_size, position, orientation, 
                    random_state=None, **kwargs):
    return 'hsl(0, 0%%, %d%%)' % random.randint(60,100)

# %%
plt.figure(figsize=(12,12))
plt.imshow(wc.recolor(color_func=grey_color_func, random_state=3),
          interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## 8-4 육아휴직 관련 법안에 대한 분석

# %% [markdown]
# 이번 절 내용은 8-1절에서 소개한 Lucy Park 님의 KoNLPy가 내장하고 있는 법률 문서 중 하나를 가지고 기초적인 분석을 해보는 튜토리얼을 아주 미세한 부분 일부를 수정해서 학습해 볼 것이다.

# %%
import nltk

# %%
from konlpy.corpus import kobill
files_ko = kobill.fileids()
doc_ko = kobill.open('1809890.txt').read()

# %%
doc_ko
# Out:
# '지방공무원법 일부개정법률안\n\n(정의화의원 대표발의 )\n\n 의 안\n 번 호\n\n9890\n\n발의연월일 : 2010.  11.  12.  \n\n발  의  자 : 정의화․이명수․김을동 \n\n이사철․여상규․안규백\n\n황영철․박영아․김정훈\n\n김학송 의원(10인)\n\n제안이유 및 주요내용\n\n  초등학교 저학년의 경우에도 부모의 따뜻한 사랑과 보살핌이 필요\n\n한 나이이나, 현재 공무원이 자녀를 양육하기 위하여 육아휴직을 할 \n\n수 있는 자녀의 나이는 만 6세 이하로 되어 있어 초등학교 저학년인 \n\n자녀를 돌보기 위해서는 해당 부모님은 일자리를 그만 두어야 하고 \n\n이는 곧 출산의욕을 저하시키는 문제로 이어질 수 있을 것임.\n\n  따라서 육아휴직이 가능한 자녀의 연령을 만 8세 이하로 개정하려\n\n는 것임(안 제63조제2항제4호).\n\n- 1 -\n\n\x0c법률  제        호\n\n지방공무원법 일부개정법률안\n\n지방공무원법 일부를 다음과 같이 개정한다.\n\n제63조제2항제4호 중 “만 6세 이하의 초등학교 취학 전 자녀를”을 “만 \n\n8세 이하(취학 중인 경우에는 초등학교 2학년 이하를 말한다)의 자녀를”\n\n로 한다.\n\n부      칙\n\n이 법은 공포한 날부터 시행한다.\n\n- 3 -\n\n\x0c신 ·구조문대비표\n\n현      행\n\n개   정   안\n\n제63조(휴직) ① (생  략)\n\n제63조(휴직) ① (현행과 같음)\n\n  ② 공무원이 다음 각 호의 어\n\n  ② -------------------------\n\n느 하나에 해당하는 사유로 휴\n\n----------------------------\n\n직을 원하면 임용권자는 휴직\n\n----------------------------\n\n을 명할 수 있다. 다만, 제4호\n\n-------------.---------------\n\n의 경우에는 대통령령으로 정\n\n-------------------------
# ...

# %% [markdown]
# 이 문서를 Twitter 분석기로 명사 분석을 하겠다.

# %%
from konlpy.tag import Twitter

t = Twitter()
tokens_ko = t.nouns(doc_ko)
tokens_ko
# Out:
# ['지방공무원법',
#  '일부',
#  '개정',
#  '법률',
#  '안',
#  '정의화',
#  '의원',
#  '대표',
#  '발의',
#  '의',
#  '안',
#  '번',
#  '호',
#  '발의',
#  '연월일',
#  '발',
#  '의',
#  '자',
#  '정의화',
#  '이명수',
#  '김을동',
#  '이사철',
#  '여상규',
#  '안규백',
#  '황영철',
#  '박영아',
#  '김정훈',
#  '김학송',
#  '의원',
#  '인',
#  '제안',
#  '이유',
#  '및',
#  '주요',
#  '내용',
#  '초등학교',
#  '저학년',
#  '경우',
#  '부모',
#  '사랑',
#  '필요',
#  '나이',
#  '현재',
#  '공무원',
#  '자녀',
#  '양육',
#  '육아휴직',
#  '수',
#  '자녀',
#  '나이',
#  '만',
#  '세',
#  '이하',
#  '초등학교',
#  '저학년',
#  '자녀',
#  '해당',
#  '부모님',
#  '일자리',
#  '곧',
#  '출산',
#  '의욕',
#  '저하',
#  '문제',
#  '수',
#  '것임',
#  '따라서',
#  '육아휴직',
#  '자녀',
#  '연령',
#  '만',
#  '세',
#  '이하',
#  '개정',
#  '것임',
#  '안',
#  '제',
#  '조제',
#  '항제',
#  '호',
#  '법률',
#  '제',
#  '호',
#  '지방공무원법',
#  '일부',
#  '개정',
#  '법률',
#  '안',
#  '지방공무원법',
#  '일부',
#  '다음',
#  '개정',
#  '제',
#  '조제',
#  '항제',
#  '호',
#  '중',
#  '만',
#  '세',
#  '이하',
#  '초등학교',
#  '취학',
#  '전',
#  '자녀',
#  '만',
#  '세',
#  '이하',
#  '취학',
#  '중인',
#  '경우',
# ...

# %% [markdown]
# 그리고 수집된 단어의 횟수(len(ko.tokens))와 고유한 횟수(len(set(ko.tokens)))를 확인한다.

# %%
ko = nltk.Text(tokens_ko, name = '대한민국 국회 의안 제 1809890호')

# %%
print(len(ko.tokens)) # returns number of tokens (document length)
print(len(set(ko.tokens))) # returns number of unique tokens
ko.vocab() # returns frequency of distribution
# Out:
# 735
# 258
# FreqDist({'가능': 4,
#           '가정': 7,
#           '각': 1,
#           '값': 2,
#           '개': 1,
#           '개정': 8,
#           '개정안': 3,
#           '거나': 1,
#           '것': 6,
#           '것임': 2,
#           '경비': 1,
#           '경우': 16,
#           '고': 1,
#           '고용': 14,
#           '고용노동부': 3,
#           '곧': 1,
#           '공': 1,
#           '공무원': 10,
#           '공포': 1,
#           '관련': 2,
#           '교육': 4,
#           '구조': 1,
#           '국가': 2,
#           '국가공무원': 2,
#           '국회예산정책처': 2,
#           '규정': 1,
#           '규칙': 1,
#           '근거': 1,
#           '근로자': 3,
#           '급여': 8,
#           '기': 1,
#           '기간': 1,
#           '기업체': 1,
#           '기자': 1,
#           '김': 1,
#           '김을동': 1,
#           '김정훈': 1,
#           '김학송': 1,
#           '까지': 1,
#           '나이': 2,
#           '날': 1,
#           '남녀': 1,
#           '내용': 1,
#           '년': 7,
#           '논의': 1,
#           '느': 1,
# ...

# %%
plt.figure(figsize =(12,6))
ko.plot(50)
plt.show()

# %% [markdown]
# 한글은 영어와 달리 stopwords를 지정하기 쉽지 않다. 그래서 case-by-case로 지정하겠다.

# %%
stop_words = ['.', '(', ')', ',', "'", '%', '-', 'X', ').', '×','의','자','에','안','번',
                      '호','을','이','다','만','로','가','를']

ko = [each_word for each_word in ko if each_word not in stop_words]
ko
# Out:
# ['지방공무원법',
#  '일부',
#  '개정',
#  '법률',
#  '정의화',
#  '의원',
#  '대표',
#  '발의',
#  '발의',
#  '연월일',
#  '발',
#  '정의화',
#  '이명수',
#  '김을동',
#  '이사철',
#  '여상규',
#  '안규백',
#  '황영철',
#  '박영아',
#  '김정훈',
#  '김학송',
#  '의원',
#  '인',
#  '제안',
#  '이유',
#  '및',
#  '주요',
#  '내용',
#  '초등학교',
#  '저학년',
#  '경우',
#  '부모',
#  '사랑',
#  '필요',
#  '나이',
#  '현재',
#  '공무원',
#  '자녀',
#  '양육',
#  '육아휴직',
#  '수',
#  '자녀',
#  '나이',
#  '세',
#  '이하',
#  '초등학교',
#  '저학년',
#  '자녀',
#  '해당',
#  '부모님',
#  '일자리',
#  '곧',
#  '출산',
#  '의욕',
#  '저하',
#  '문제',
#  '수',
#  '것임',
#  '따라서',
#  '육아휴직',
#  '자녀',
#  '연령',
#  '세',
#  '이하',
#  '개정',
#  '것임',
#  '제',
#  '조제',
#  '항제',
#  '법률',
#  '제',
#  '지방공무원법',
#  '일부',
#  '개정',
#  '법률',
#  '지방공무원법',
#  '일부',
#  '다음',
#  '개정',
#  '제',
#  '조제',
#  '항제',
#  '중',
#  '세',
#  '이하',
#  '초등학교',
#  '취학',
#  '전',
#  '자녀',
#  '세',
#  '이하',
#  '취학',
#  '중인',
#  '경우',
#  '초등학교',
#  '학년',
#  '이하',
#  '자녀',
#  '부',
#  '칙',
#  '법',
#  '공포',
#  '날',
#  '시행',
#  '신',
#  '구조',
#  '문대비',
#  '표',
# ...

# %%
ko = nltk.Text(tokens_ko, name = '대한민국 국회 의안 제 1809890호')

plt.figure(figsize =(12,6))
ko.plot(50)
plt.show()

# %%
ko.count('초등학교')
# Out:
# 6

# %% [markdown]
# 어떤 단어가 문서 내에서 몇 번 언급되었는지 확인할 수 있다.

# %%
# 원하는 단어의 문서 내 위치를 개략적으로 그 분량과 함께 알 수 있다.

plt.figure(figsize=(12,6))
ko.dispersion_plot(['육아휴직','초등학교','공무원'])

# %%
ko.concordance('초등학교')
# Out:
# Displaying 6 of 6 matches:
# 백 황영철 박영아 김정훈 김학송 의원 인 제안 이유 및 주요 내용 초등학교 저학년 경우 부모 사랑 필요 나이 현재 공무원 자녀 양육 육아휴직
#  나이 현재 공무원 자녀 양육 육아휴직 수 자녀 나이 만 세 이하 초등학교 저학년 자녀 해당 부모님 일자리 곧 출산 의욕 저하 문제 수 것임
# 안 지방공무원법 일부 다음 개정 제 조제 항제 호 중 만 세 이하 초등학교 취학 전 자녀 만 세 이하 취학 중인 경우 초등학교 학년 이하 의
#  만 세 이하 초등학교 취학 전 자녀 만 세 이하 취학 중인 경우 초등학교 학년 이하 의 자녀 로 부 칙 이 법 공포 날 시행 신 구조 문대
# 제 호 의 경우 대통령령 정 사정 직 명 생 략 현행 만 세 이하 초등학교 취 만 세 이하 취학 중인 경우 학 전 자녀 양육 위하 초등학교
#  초등학교 취 만 세 이하 취학 중인 경우 학 전 자녀 양육 위하 초등학교 학년 이하 여 여자 공무원 의 자녀 임신 출산 때 생 략 생 략

# %% [markdown]
# 원하는 단어의 주변부 단어까지 같이 확인할 수 있다. 또 문서 내에서 어떤 단어들이 연이어(collocation) 사용되었는지 알 수 있다.

# %%
ko.collocations()
# Out:
# 초등학교 저학년; 근로자 육아휴직; 육아휴직 대상자; 공무원 육아휴직

# %%
data = ko.vocab().most_common(150)

# for win : font_path='c:/Windows/Fonts/malgun.ttf'
wordcloud = WordCloud(font_path='/Library/Fonts/AppleGothic.ttf',
                      relative_scaling = 0.2,
                      background_color='white',
                      ).generate_from_frequencies(dict(data))
plt.figure(figsize=(12,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
